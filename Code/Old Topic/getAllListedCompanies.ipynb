# %%
import pandas as pd

# %%
companyName = pd.read_csv("../Data/ListedCompanies/listedCompanies.csv",skiprows=1)

# %%
companyName.head(10)
# Out:
#   หลักทรัพย์                                             บริษัท ตลาด  \
# 0         2S                   บริษัท 2 เอส เมทัล จำกัด (มหาชน)  SET
# 1     3K-BAT  บริษัท ไทย เอ็นเนอร์จี สโตเรจ เทคโนโลยี จำกัด ...  SET
# 2        7UP  บริษัท เซเว่น ยูทิลิตี้ส์ แอนด์ พาวเวอร์ จำกัด...  SET
# 3          A           บริษัท อารียา พรอพเพอร์ตี้ จำกัด (มหาชน)  SET
# 4         A5             บริษัท แอสเซท ไฟว์ กรุ๊ป จำกัด (มหาชน)  mai
# 5        AAV             บริษัท เอเชีย เอวิเอชั่น จำกัด (มหาชน)  SET
# 6      ABICO             บริษัท เอบิโก้ โฮลดิ้งส์ จำกัด (มหาชน)  mai
# 7        ABM                บริษัท เอเชีย ไบโอแมส จำกัด (มหาชน)  mai
# 8      ABPIF  กองทุนรวมโครงสร้างพื้นฐานโรงไฟฟ้า อมตะ บี.กริม...  SET
# 9       ACAP         บริษัท เอเชีย แคปปิตอล กรุ๊ป จำกัด (มหาชน)  mai
#
#               กลุ่มอุตสาหกรรม               หมวดธุรกิจ  \
# 0            สินค้าอุตสาหกรรม  เหล็ก และ ผลิตภัณฑ์โลหะ
# 1            สินค้าอุตสาหกรรม                  ยานยนต์
# ...

# %%
companyName.drop(columns=["บริษัท",	"ตลาด",	"กลุ่มอุตสาหกรรม", "หมวดธุรกิจ", "ที่อยู่", "รหัสไปรษณีย์", "โทรศัพท์", "โทรสาร", "เว๊บไซต์"], inplace=True)
companyName
# Out:
#     หลักทรัพย์
# 0           2S
# 1       3K-BAT
# 2          7UP
# 3            A
# 4           A5
# ..         ...
# 843        XPG
# 844        YGG
# 845      YUASA
# 846        ZEN
# 847       ZIGA
#
# [848 rows x 1 columns]

# %%
companyName.to_csv('listedCompaniesNameOnly.csv', index=False)
